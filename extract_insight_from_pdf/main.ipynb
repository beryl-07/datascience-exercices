# %%
import tabula

# %%
dfs = tabula.read_pdf('./fichier1.pdf', pages='all')
# Out:
# Got stderr: Apr 11, 2025 10:32:12 AM org.apache.pdfbox.pdmodel.graphics.color.PDICCBased ensureDisplayProfile
# WARNING: ICC profile is Perceptual, ignoring, treating as Display class
# Apr 11, 2025 10:32:13 AM org.apache.pdfbox.pdmodel.graphics.color.PDICCBased ensureDisplayProfile
# WARNING: ICC profile is Perceptual, ignoring, treating as Display class
# Apr 11, 2025 10:32:14 AM org.apache.pdfbox.pdmodel.graphics.color.PDICCBased ensureDisplayProfile
# WARNING: ICC profile is Perceptual, ignoring, treating as Display class
# Apr 11, 2025 10:32:14 AM org.apache.pdfbox.pdmodel.graphics.color.PDICCBased ensureDisplayProfile
# WARNING: ICC profile is Perceptual, ignoring, treating as Display class
# Apr 11, 2025 10:32:15 AM org.apache.pdfbox.pdmodel.graphics.color.PDICCBased ensureDisplayProfile
# WARNING: ICC profile is Perceptual, ignoring, treating as Display class
# Apr 11, 2025 10:32:15 AM org.apache.pdfbox.pdmodel.graphics.color.PDICCBased ensureDisplayProfile
# ...

# %%
df=dfs[0]
df
# Out:
#                            Unnamed: 0 Unnamed: 1  Control  \
# 0             Final BW per 1000 birds         kg   2135.0
# 1            Live broiler sales price       €/kg      1.5
# 2              Revenue per 1000 birds          €   3202.5
# 3          Feed intake per 1000 birds         kg   4006.6
# 4     Cost of additive per 1000 birds          €      NaN
# 5     Total feed cost per 1000 birds*          €   1561.8
# 6  Contribution margin per 1000 birds        NaN      NaN
# 7                (=Revenue-feed cost)          €   1640.7
# 8                  ROI per 1000 birds        NaN      NaN
#
#    Digestarom®  P.E.P.  Difference
# 0               2210.0        75.0
# 1                  1.5         NaN
# 2               3315.0       112.5
# 3               4062.1        55.5
# 4                 12.7         NaN
# 5               1596.1        34.3
# 6                  NaN         NaN
# 7               1718.9        78.2
# 8                  6.2         NaN

# %%
df.loc[7, 'Unnamed: 0'] = df.loc[6, 'Unnamed: 0'] + df.loc[7, 'Unnamed: 0']
df.drop(index=6, inplace=True)
df
# Out:
#                                           Unnamed: 0 Unnamed: 1  Control  \
# 0                            Final BW per 1000 birds         kg   2135.0
# 1                           Live broiler sales price       €/kg      1.5
# 2                             Revenue per 1000 birds          €   3202.5
# 3                         Feed intake per 1000 birds         kg   4006.6
# 4                    Cost of additive per 1000 birds          €      NaN
# 5                    Total feed cost per 1000 birds*          €   1561.8
# 7  Contribution margin per 1000 birds(=Revenue-fe...          €   1640.7
# 8                                 ROI per 1000 birds        NaN      NaN
#
#    Digestarom®  P.E.P.  Difference
# 0               2210.0        75.0
# 1                  1.5         NaN
# 2               3315.0       112.5
# 3               4062.1        55.5
# 4                 12.7         NaN
# 5               1596.1        34.3
# 7               1718.9        78.2
# ...

# %%
df.rename(
    columns={
        'Unnamed: 0': 'Unnamed',
        'Unnamed: 1': 'Unit'
}, inplace=True)
df
# Out:
#                                              Unnamed  Unit  Control  \
# 0                            Final BW per 1000 birds    kg   2135.0
# 1                           Live broiler sales price  €/kg      1.5
# 2                             Revenue per 1000 birds     €   3202.5
# 3                         Feed intake per 1000 birds    kg   4006.6
# 4                    Cost of additive per 1000 birds     €      NaN
# 5                    Total feed cost per 1000 birds*     €   1561.8
# 7  Contribution margin per 1000 birds(=Revenue-fe...     €   1640.7
# 8                                 ROI per 1000 birds   NaN      NaN
#
#    Digestarom®  P.E.P.  Difference
# 0               2210.0        75.0
# 1                  1.5         NaN
# 2               3315.0       112.5
# 3               4062.1        55.5
# 4                 12.7         NaN
# 5               1596.1        34.3
# 7               1718.9        78.2
# 8                  6.2         NaN
